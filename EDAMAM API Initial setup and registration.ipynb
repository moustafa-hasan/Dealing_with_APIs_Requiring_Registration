# %% [markdown]
# ## Dealing with APIs which require registration

# %% [markdown]
# ### Intial Setup

# %%
import requests
import json

# %%
APP_ID = "###############"
APP_KEY = "#################################"

# %%
api_endpoint = "https://api.edamam.com/api/nutrition-details"

url = api_endpoint + "?app_id=" + APP_ID + "&app_key=" + APP_KEY

# %% [markdown]
# ### Sending a POST request

# %%
headers = {
    'content-Type' : 'application/json'
}

# %%
recipe = {
  "title": "Cappuccino",
  "ingr": ["20g ground espresso", "200ml milk"]
}

# %%
r = requests.post(url, headers = headers, json = recipe)
r.status_code
# Out:
# 200

# %% [markdown]
# ### Inspecting the response

# %%
capp_info = r.json()

# %%
print(json.dumps(capp_info, indent = 4))
# Out:
# {
#     "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_3071a5c34ae84c719e157e970ebcacc5",
#     "yield": 2.0,
#     "calories": 127,
#     "totalWeight": 226.26553848124226,
#     "dietLabels": [
#         "LOW_SODIUM"
#     ],
#     "healthLabels": [
#         "LOW_POTASSIUM",
#         "KIDNEY_FRIENDLY",
#         "KETO_FRIENDLY",
#         "VEGETARIAN",
#         "PESCATARIAN",
#         "MEDITERRANEAN",
#         "GLUTEN_FREE",
#         "WHEAT_FREE",
#         "EGG_FREE",
#         "PEANUT_FREE",
#         "TREE_NUT_FREE",
#         "SOY_FREE",
#         "FISH_FREE",
#         "SHELLFISH_FREE",
#         "PORK_FREE",
#         "RED_MEAT_FREE",
#         "CRUSTACEAN_FREE",
#         "CELERY_FREE",
#         "MUSTARD_FREE",
#         "SESAME_FREE",
#         "LUPINE_FREE",
#         "MOLLUSK_FREE",
#         "ALCOHOL_FREE",
#         "NO_OIL_ADDED",
#         "NO_SUGAR_ADDED",
#         "SULPHITE_FREE",
#         "KOSHER"
#     ],
#     "cautions": [
#         "SULFITES"
#     ],
#     "totalNutrients": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 127.62197847355779,
#             "unit": "kcal"
#         },
#         "FAT": {
#             "label": "Total lipid (fat)",
#             "quantity": 6.739630000640373,
#             "unit": "g"
#         },
#         "FASAT": {
#             "label": "Fatty acids, total saturated",
#             "quantity": 3.8652522926751685,
#             "unit": "g"
#         },
#         "FATRN": {
#             "label": "Fatty acids, total trans",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "FAMS": {
#             "label": "Fatty acids, total monounsaturated",
#             "quantity": 1.6748761724676873,
#             "unit": "g"
#         },
#         "FAPU": {
#             "label": "Fatty acids, total polyunsaturated",
#             "quantity": 0.4206178000384224,
#             "unit": "g"
#         },
#         "CHOCDF": {
#             "label": "Carbohydrate, by difference",
#             "quantity": 10.234745847099628,
#             "unit": "g"
#         },
#         "FIBTG": {
#             "label": "Fiber, total dietary",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "SUGAR": {
#             "label": "Sugars, total",
#             "quantity": 10.416409693302734,
#             "unit": "g"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 6.521364462159132,
#             "unit": "g"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 20.626553848124228,
#             "unit": "mg"
#         },
#         "NA": {
#             "label": "Sodium, Na",
#             "quantity": 91.49418154693417,
#             "unit": "mg"
#         },
#         "CA": {
#             "label": "Calcium, Ca",
#             "quantity": 233.48005848380376,
#             "unit": "mg"
#         },
#         "MG": {
#             "label": "Magnesium, Mg",
#             "quantity": 36.62655384812423,
#             "unit": "mg"
#         },
#         "K": {
#             "label": "Potassium, K",
#             "quantity": 295.2705107952398,
#             "unit": "mg"
#         },
#         "FE": {
#             "label": "Iron, Fe",
#             "quantity": 0.08787966154437268,
#             "unit": "mg"
#         },
#         "ZN": {
#             "label": "Zinc, Zn",
#             "quantity": 0.7731824923805964,
#             "unit": "mg"
#         },
#         "P": {
#             "label": "Phosphorus, P",
#             "quantity": 174.66305232424352,
#             "unit": "mg"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A, RAE",
#             "quantity": 94.88214770137145,
#             "unit": "\u00b5g"
#         },
#         "VITC": {
#             "label": "Vitamin C, total ascorbic acid",
#             "quantity": 0.04000000000000001,
#             "unit": "mg"
#         },
#         "THIA": {
#             "label": "Thiamin",
#             "quantity": 0.09508214770137145,
#             "unit": "mg"
#         },
#         "RIBF": {
#             "label": "Riboflavin",
#             "quantity": 0.38398876003329946,
#             "unit": "mg"
#         },
#         "NIA": {
#             "label": "Niacin",
#             "quantity": 1.2249763292483058,
#             "unit": "mg"
#         },
#         "VITB6A": {
#             "label": "Vitamin B-6",
#             "quantity": 0.07465559385324722,
#             "unit": "mg"
#         },
#         "FOLDFE": {
#             "label": "Folate, DFE",
#             "quantity": 10.513276924062113,
#             "unit": "\u00b5g"
#         },
#         "FOLFD": {
#             "label": "Folate, food",
#             "quantity": 10.513276924062113,
#             "unit": "\u00b5g"
#         },
#         "FOLAC": {
#             "label": "Folic acid",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITB12": {
#             "label": "Vitamin B-12",
#             "quantity": 0.9281949231655903,
#             "unit": "\u00b5g"
#         },
#         "VITD": {
#             "label": "Vitamin D (D2 + D3)",
#             "quantity": 2.6814520002561495,
#             "unit": "\u00b5g"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E (alpha-tocopherol)",
#             "quantity": 0.1463858769368696,
#             "unit": "mg"
#         },
#         "VITK1": {
#             "label": "Vitamin K (phylloquinone)",
#             "quantity": 0.6387966154437268,
#             "unit": "\u00b5g"
#         },
#         "WATER": {
#             "label": "Water",
#             "quantity": 201.3418190635188,
#             "unit": "g"
#         }
#     },
#     "totalDaily": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 6.3810989236778894,
#             "unit": "%"
#         },
#         "FAT": {
#             "label": "Fat",
#             "quantity": 10.368661539446727,
#             "unit": "%"
#         },
#         "FASAT": {
#             "label": "Saturated",
#             "quantity": 19.326261463375843,
#             "unit": "%"
#         },
#         "CHOCDF": {
#             "label": "Carbs",
#             "quantity": 3.4115819490332093,
#             "unit": "%"
#         },
#         "FIBTG": {
#             "label": "Fiber",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 13.042728924318261,
#             "unit": "%"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 6.875517949374742,
#             "unit": "%"
#         },
#         "NA": {
#             "label": "Sodium",
#             "quantity": 3.812257564455591,
#             "unit": "%"
#         },
#         "CA": {
#             "label": "Calcium",
#             "quantity": 23.348005848380378,
#             "unit": "%"
#         },
#         "MG": {
#             "label": "Magnesium",
#             "quantity": 8.720608059077199,
#             "unit": "%"
#         },
#         "K": {
#             "label": "Potassium",
#             "quantity": 6.28235129351574,
#             "unit": "%"
#         },
#         "FE": {
#             "label": "Iron",
#             "quantity": 0.48822034191318164,
#             "unit": "%"
#         },
#         "ZN": {
#             "label": "Zinc",
#             "quantity": 7.0289317489145136,
#             "unit": "%"
#         },
#         "P": {
#             "label": "Phosphorus",
#             "quantity": 24.951864617749074,
#             "unit": "%"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A",
#             "quantity": 10.542460855707938,
#             "unit": "%"
#         },
#         "VITC": {
#             "label": "Vitamin C",
#             "quantity": 0.04444444444444445,
#             "unit": "%"
#         },
#         "THIA": {
#             "label": "Thiamin (B1)",
#             "quantity": 7.923512308447622,
#             "unit": "%"
#         },
#         "RIBF": {
#             "label": "Riboflavin (B2)",
#             "quantity": 29.537596925638418,
#             "unit": "%"
#         },
#         "NIA": {
#             "label": "Niacin (B3)",
#             "quantity": 7.656102057801911,
#             "unit": "%"
#         },
#         "VITB6A": {
#             "label": "Vitamin B6",
#             "quantity": 5.7427379887113235,
#             "unit": "%"
#         },
#         "FOLDFE": {
#             "label": "Folate equivalent (total)",
#             "quantity": 2.6283192310155283,
#             "unit": "%"
#         },
#         "VITB12": {
#             "label": "Vitamin B12",
#             "quantity": 38.67478846523293,
#             "unit": "%"
#         },
#         "VITD": {
#             "label": "Vitamin D",
#             "quantity": 17.876346668374328,
#             "unit": "%"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E",
#             "quantity": 0.9759058462457975,
#             "unit": "%"
#         },
#         "VITK1": {
#             "label": "Vitamin K",
#             "quantity": 0.5323305128697723,
#             "unit": "%"
#         }
#     },
#     "totalNutrientsKCal": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 128,
#             "unit": "kcal"
#         },
#         "PROCNT_KCAL": {
#             "label": "Calories from protein",
#             "quantity": 26,
#             "unit": "kcal"
#         },
#         "FAT_KCAL": {
#             "label": "Calories from fat",
#             "quantity": 61,
#             "unit": "kcal"
#         },
#         "CHOCDF_KCAL": {
#             "label": "Calories from carbohydrates",
#             "quantity": 41,
#             "unit": "kcal"
#         }
#     }
# }

# %%
capp_info.keys()
# Out:
# dict_keys(['uri', 'yield', 'calories', 'totalWeight', 'dietLabels', 'healthLabels', 'cautions', 'totalNutrients', 'totalDaily', 'totalNutrientsKCal'])

# %%
print(json.dumps(capp_info["totalNutrients"], indent = 4))
# Out:
# {
#     "ENERC_KCAL": {
#         "label": "Energy",
#         "quantity": 127.62197847355779,
#         "unit": "kcal"
#     },
#     "FAT": {
#         "label": "Total lipid (fat)",
#         "quantity": 6.739630000640373,
#         "unit": "g"
#     },
#     "FASAT": {
#         "label": "Fatty acids, total saturated",
#         "quantity": 3.8652522926751685,
#         "unit": "g"
#     },
#     "FATRN": {
#         "label": "Fatty acids, total trans",
#         "quantity": 0.0,
#         "unit": "g"
#     },
#     "FAMS": {
#         "label": "Fatty acids, total monounsaturated",
#         "quantity": 1.6748761724676873,
#         "unit": "g"
#     },
#     "FAPU": {
#         "label": "Fatty acids, total polyunsaturated",
#         "quantity": 0.4206178000384224,
#         "unit": "g"
#     },
#     "CHOCDF": {
#         "label": "Carbohydrate, by difference",
#         "quantity": 10.234745847099628,
#         "unit": "g"
#     },
#     "FIBTG": {
#         "label": "Fiber, total dietary",
#         "quantity": 0.0,
#         "unit": "g"
#     },
#     "SUGAR": {
#         "label": "Sugars, total",
#         "quantity": 10.416409693302734,
#         "unit": "g"
#     },
#     "PROCNT": {
#         "label": "Protein",
#         "quantity": 6.521364462159132,
#         "unit": "g"
#     },
#     "CHOLE": {
#         "label": "Cholesterol",
#         "quantity": 20.626553848124228,
#         "unit": "mg"
#     },
#     "NA": {
#         "label": "Sodium, Na",
#         "quantity": 91.49418154693417,
#         "unit": "mg"
#     },
#     "CA": {
#         "label": "Calcium, Ca",
#         "quantity": 233.48005848380376,
#         "unit": "mg"
#     },
#     "MG": {
#         "label": "Magnesium, Mg",
#         "quantity": 36.62655384812423,
#         "unit": "mg"
#     },
#     "K": {
#         "label": "Potassium, K",
#         "quantity": 295.2705107952398,
#         "unit": "mg"
#     },
#     "FE": {
#         "label": "Iron, Fe",
#         "quantity": 0.08787966154437268,
#         "unit": "mg"
#     },
#     "ZN": {
#         "label": "Zinc, Zn",
#         "quantity": 0.7731824923805964,
#         "unit": "mg"
#     },
#     "P": {
#         "label": "Phosphorus, P",
#         "quantity": 174.66305232424352,
#         "unit": "mg"
#     },
#     "VITA_RAE": {
#         "label": "Vitamin A, RAE",
#         "quantity": 94.88214770137145,
#         "unit": "\u00b5g"
#     },
#     "VITC": {
#         "label": "Vitamin C, total ascorbic acid",
#         "quantity": 0.04000000000000001,
#         "unit": "mg"
#     },
#     "THIA": {
#         "label": "Thiamin",
#         "quantity": 0.09508214770137145,
#         "unit": "mg"
#     },
#     "RIBF": {
#         "label": "Riboflavin",
#         "quantity": 0.38398876003329946,
#         "unit": "mg"
#     },
#     "NIA": {
#         "label": "Niacin",
#         "quantity": 1.2249763292483058,
#         "unit": "mg"
#     },
#     "VITB6A": {
#         "label": "Vitamin B-6",
#         "quantity": 0.07465559385324722,
#         "unit": "mg"
#     },
#     "FOLDFE": {
#         "label": "Folate, DFE",
#         "quantity": 10.513276924062113,
#         "unit": "\u00b5g"
#     },
#     "FOLFD": {
#         "label": "Folate, food",
#         "quantity": 10.513276924062113,
#         "unit": "\u00b5g"
#     },
#     "FOLAC": {
#         "label": "Folic acid",
#         "quantity": 0.0,
#         "unit": "\u00b5g"
#     },
#     "VITB12": {
#         "label": "Vitamin B-12",
#         "quantity": 0.9281949231655903,
#         "unit": "\u00b5g"
#     },
#     "VITD": {
#         "label": "Vitamin D (D2 + D3)",
#         "quantity": 2.6814520002561495,
#         "unit": "\u00b5g"
#     },
#     "TOCPHA": {
#         "label": "Vitamin E (alpha-tocopherol)",
#         "quantity": 0.1463858769368696,
#         "unit": "mg"
#     },
#     "VITK1": {
#         "label": "Vitamin K (phylloquinone)",
#         "quantity": 0.6387966154437268,
#         "unit": "\u00b5g"
#     },
#     "WATER": {
#         "label": "Water",
#         "quantity": 201.3418190635188,
#         "unit": "g"
#     }
# }

# %%
capp_info["totalNutrients"]["SUGAR"]
# Out:
# {'label': 'Sugars, total', 'quantity': 10.416409693302734, 'unit': 'g'}

# %% [markdown]
# ### Structuring and exporting the data

# %%
import pandas as pd

# %%
pd.DataFrame(capp_info["totalNutrients"])
# Out:
#           ENERC_KCAL                FAT                         FASAT  \
# label         Energy  Total lipid (fat)  Fatty acids, total saturated
# quantity  127.621978            6.73963                      3.865252
# unit            kcal                  g                             g
#
#                              FATRN                                FAMS  \
# label     Fatty acids, total trans  Fatty acids, total monounsaturated
# quantity                       0.0                            1.674876
# unit                             g                                   g
#
#                                         FAPU                       CHOCDF  \
# label     Fatty acids, total polyunsaturated  Carbohydrate, by difference
# quantity                            0.420618                    10.234746
# unit                                       g                            g
#
#                          FIBTG          SUGAR    PROCNT  ...       NIA  \
# label     Fiber, total dietary  Sugars, total   Protein  ...    Niacin
# quantity                   0.0       10.41641  6.521364  ...  1.224976
# unit                         g              g         g  ...        mg
#
#                VITB6A       FOLDFE         FOLFD       FOLAC        VITB12  \
# label     Vitamin B-6  Folate, DFE  Folate, food  Folic acid  Vitamin B-12
# quantity     0.074656    10.513277     10.513277         0.0      0.928195
# unit               mg           µg            µg          µg            µg
#
#                          VITD                        TOCPHA  \
# label     Vitamin D (D2 + D3)  Vitamin E (alpha-tocopherol)
# quantity             2.681452                      0.146386
# unit                       µg                            mg
#
#                               VITK1       WATER
# label     Vitamin K (phylloquinone)       Water
# quantity                   0.638797  201.341819
# unit                             µg           g
#
# [3 rows x 32 columns]

# %%
# To convert to vertical
capp_nutrients = pd.DataFrame(capp_info["totalNutrients"]).transpose()
capp_nutrients
# Out:
#                                          label    quantity  unit
# ENERC_KCAL                              Energy  127.621978  kcal
# FAT                          Total lipid (fat)     6.73963     g
# FASAT             Fatty acids, total saturated    3.865252     g
# FATRN                 Fatty acids, total trans         0.0     g
# FAMS        Fatty acids, total monounsaturated    1.674876     g
# FAPU        Fatty acids, total polyunsaturated    0.420618     g
# CHOCDF             Carbohydrate, by difference   10.234746     g
# FIBTG                     Fiber, total dietary         0.0     g
# SUGAR                            Sugars, total    10.41641     g
# PROCNT                                 Protein    6.521364     g
# CHOLE                              Cholesterol   20.626554    mg
# NA                                  Sodium, Na   91.494182    mg
# CA                                 Calcium, Ca  233.480058    mg
# MG                               Magnesium, Mg   36.626554    mg
# K                                 Potassium, K  295.270511    mg
# FE                                    Iron, Fe     0.08788    mg
# ZN                                    Zinc, Zn    0.773182    mg
# P                                Phosphorus, P  174.663052    mg
# VITA_RAE                        Vitamin A, RAE   94.882148    µg
# VITC            Vitamin C, total ascorbic acid        0.04    mg
# THIA                                   Thiamin    0.095082    mg
# RIBF                                Riboflavin    0.383989    mg
# NIA                                     Niacin    1.224976    mg
# VITB6A                             Vitamin B-6    0.074656    mg
# FOLDFE                             Folate, DFE   10.513277    µg
# FOLFD                             Folate, food   10.513277    µg
# FOLAC                               Folic acid         0.0    µg
# VITB12                            Vitamin B-12    0.928195    µg
# VITD                       Vitamin D (D2 + D3)    2.681452    µg
# TOCPHA            Vitamin E (alpha-tocopherol)    0.146386    mg
# VITK1                Vitamin K (phylloquinone)    0.638797    µg
# WATER                                    Water  201.341819     g

# %%
capp_nutrients.to_csv("Cappuccino_nutrients.csv")

# %% [markdown]
# ### Testing invalid input

# %%
cake = requests.post(url, headers = headers, json = {"title" : "Pizza"})
cake.status_code
# Out:
# 500
